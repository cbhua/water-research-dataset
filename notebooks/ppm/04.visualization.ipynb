# %%
import sys; sys.path.append(2 * "../")

# Packages
import pandas as pd
import numpy as np

from src.utils import (
    plot_1d,
)

# Repository root path
root = 2 * "../"

# %% [markdown]
# ### Minute Original Data Visualization

# %%
# Load the data
minute_data = pd.read_csv(root + "data/ppm/ori/minute.csv")
print(f"Minute Data Range: {minute_data['DateTime'][0]} ~ {minute_data['DateTime'][minute_data.shape[0]-1]}")
print(f"Minute Data Shape: {minute_data.shape}")
minute_data.head()
# Out:
# Minute Data Range: 2016-01-01 12:04:00 ~ 2021-12-31 23:59:00
# Minute Data Shape: (3086701, 13)
#               DateTime  Raw_Flow  Raw_temperature  \
# 0  2016-01-01 12:04:00   2375.00            8.900
# 1  2016-01-01 12:05:00   2375.00            8.875
# 2  2016-01-01 12:06:00   2383.75            8.875
# 3  2016-01-01 12:07:00   2376.25            8.875
# 4  2016-01-01 12:08:00   2382.50            8.875
#
#    Raw_electrical conductivity  Raw_turbidity  Raw_alkalinity  Raw_pH  \
# 0                   188.053097          2.025           33.25  7.1750
# 1                   188.191882          2.050           33.25  7.1750
# 2                   188.191882          2.050           33.25  7.1785
# 3                   188.560886          2.050           33.25  7.1785
# 4                   188.191882          2.000           33.25  7.1750
#
#     Raw_TOC        PAC  Pre_chlorine  Sed_chlorine  Sed_turbidity  \
# 0  1.668937  13.721414          2.30          1.03           0.27
# ...

# %%
# Extra the time
time = minute_data["DateTime"]
time = np.array(time, dtype='datetime64')
print(f"Time Shape: {time.shape}")
# Out:
# Time Shape: (3086701,)

# %%
plot_1d(time, minute_data["Raw_Flow"], "Raw Flow")

# %%
plot_1d(time, minute_data["Raw_temperature"], "Raw Temperature")

# %%
plot_1d(time, minute_data["Raw_electrical conductivity"], "Raw Electrical Conductivity")

# %%
plot_1d(time, minute_data["Raw_turbidity"], "Raw Turbidity")

# %%
plot_1d(time, minute_data["Raw_alkalinity"], "Raw Alkalinity")

# %%
plot_1d(time, minute_data["Raw_pH"], "Raw pH")

# %%
plot_1d(time, minute_data["Raw_TOC"], "Raw TOC")

# %%
plot_1d(time, minute_data["Pre_chlorine"], "Pre Chlorine")

# %%
plot_1d(time, minute_data["Sed_chlorine"], "Sed Chlorine")

# %%
plot_1d(time, minute_data["Sed_turbidity"], "Sed Turbidity")

# %%
plot_1d(time, minute_data["Mid_chlorine"], "Mid Chlorine")

# %% [markdown]
# ### Hour Original Data Visualization

# %%
# Load the data
hour_data = pd.read_csv(root + "data/ppm/processed/hour.csv")
print(f"Hour Data Range: {hour_data['DateTime'][0]} ~ {hour_data['DateTime'][hour_data.shape[0]-1]}")
print(f"Hour Data Shape: {hour_data.shape}")
hour_data.head()
# Out:
# Hour Data Range: 2016-01-01 12:00:00 ~ 2021-12-31 23:00:00
# Hour Data Shape: (52596, 13)
#               DateTime  Raw_Flow  Raw_temperature  \
# 0  2016-01-01 12:00:00   2375.00         8.907143
# 1  2016-01-01 13:00:00   2576.25         8.935417
# 2  2016-01-01 14:00:00   2586.25         8.954167
# 3  2016-01-01 15:00:00   2525.00         8.957083
# 4  2016-01-01 16:00:00   2455.00         8.956667
#
#    Raw_electrical conductivity  Raw_turbidity  Raw_alkalinity    Raw_pH  \
# 0                   186.921133       1.928125       33.250446  7.175125
# 1                   185.874105       1.697917       35.263333  7.170042
# 2                   187.624267       1.859167       32.963750  7.162517
# 3                   185.638802       2.089167       33.228750  7.173308
# 4                   183.033574       2.204167       32.404167  7.182467
#
#     Raw_TOC        PAC  Pre_chlorine  Sed_chlorine  Sed_turbidity  \
# 0  1.668937  10.961077      2.291607      1.038750       0.270000
# ...

# %%
# Extra the time
time = hour_data["DateTime"]
time = np.array(time, dtype='datetime64')
print(f"Time Shape: {time.shape}")
# Out:
# Time Shape: (52596,)

# %%
plot_1d(time, hour_data["Raw_Flow"], "Raw Flow")

# %%
plot_1d(time, hour_data["Raw_temperature"], "Raw Temperature")

# %%
plot_1d(time, hour_data["Raw_electrical conductivity"], "Raw Electrical Conductivity")

# %%
plot_1d(time, hour_data["Raw_turbidity"], "Raw Turbidity")

# %%
plot_1d(time, hour_data["Raw_alkalinity"], "Raw Alkalinity")

# %%
plot_1d(time, hour_data["Raw_pH"], "Raw pH")

# %%
plot_1d(time, hour_data["Raw_TOC"], "Raw TOC")

# %%
plot_1d(time, hour_data["Pre_chlorine"], "Pre Chlorine")

# %%
plot_1d(time, hour_data["Sed_chlorine"], "Sed Chlorine")

# %%
plot_1d(time, hour_data["Sed_turbidity"], "Sed Turbidity")

# %%
plot_1d(time, hour_data["Mid_chlorine"], "Mid Chlorine")
